# %% [markdown]
# <a href="https://colab.research.google.com/github/Asifhonor/Sentinel-data/blob/main/Final%20Pygmtsar6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Platform, sys, Operating Sys (os)**

# %%
import platform, sys, os

# %% [markdown]
# # **Install GMTSAR**

# %%
import os  # Import the os module

# use default GMTSAR installation path
PATH = os.environ['PATH']
if PATH.find('GMTSAR') == -1:
    PATH = os.environ['PATH'] + ':/usr/local/GMTSAR/bin/'
    # %env PATH {PATH}
# Out:
# env: PATH=/opt/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/usr/local/GMTSAR/bin/

# %%
import sys
import subprocess
# use default GMTSAR installation path if it's not already in PATH
if 'GMTSAR' not in os.environ['PATH']:
    os.environ['PATH'] += ':/usr/local/GMTSAR/bin/'

if 'google.colab' in sys.modules:
    count = !ls /usr/local | grep GMTSAR | wc -l
    if count == ['0']:
        # !export DEBIAN_FRONTEND=noninteractive
        # !apt-get update > /dev/null
        # !apt install -y csh autoconf gfortran \
            libtiff5-dev libhdf5-dev liblapack-dev libgmt-dev gmt > /dev/null
        # GMTSAR codes are not so good to be compiled by modern GCC
        # !apt install gcc-9 > /dev/null
        # !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-9 10
        # !update-alternatives --config gcc
        # !gcc --version | head -n 1
        # !rm -fr /usr/local/GMTSAR
        # !git config --global advice.detachedHead false
        # !cd /usr/local && git clone -q --branch master https://github.com/gmtsar/gmtsar GMTSAR
        # revert recent broken commit
        # !cd /usr/local/GMTSAR && git checkout e98ebc0f4164939a4780b1534bac186924d7c998 > /dev/null
        # !cd /usr/local/GMTSAR && autoconf > /dev/null
        # !cd /usr/local/GMTSAR && ./configure --with-orbits-dir=/tmp > /dev/null
        # !cd /usr/local/GMTSAR && make 1>/dev/null 2>/dev/null
        # !cd /usr/local/GMTSAR && make install >/dev/null
        # fix for missed script, use bash instead of csh interpretator
        # note: csh messes stdout and stderr in Docker environment, it's resolved in PyGMTSAR code
        # !echo '#!/bin/sh' > /usr/local/GMTSAR/bin/gmtsar_sharedir.csh
        # !echo echo /usr/local/GMTSAR/share/gmtsar >> /usr/local/GMTSAR/bin/gmtsar_sharedir.csh
        # !chmod a+x /usr/local/GMTSAR/bin/gmtsar_sharedir.csh
        # !/usr/local/GMTSAR/bin/gmtsar_sharedir.csh
        # test one GMTSAR binary
        # !/usr/local/GMTSAR/bin/make_s1a_tops 2>&1 | head -n 2

# %%
import sys
import subprocess

if 'google.colab' in sys.modules:
    # Install xvfb package
    subprocess.run(['apt', 'install', '-y', 'xvfb'], check=True)

    # Install Python packages pyvista and xvfbwrapper
    subprocess.run([sys.executable, '-m', 'pip', 'install', 'pyvista', 'xvfbwrapper'], check=True)

    # Import xvfbwrapper and start virtual display
    import xvfbwrapper
    display = xvfbwrapper.Xvfb(width=800, height=600)
    display.start()

# %% [markdown]
# # **Python Version**

# %%
# !{sys.executable} --version
# Out:
# Python 3.10.12

# %% [markdown]
# # **Install Pygmtsar**

# %%
# !pip install pandas==2.0.3
# Out:
# Collecting pandas==2.0.3
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygmtsar 2024.4.17.post2 requires pandas>=2.2, but you have pandas 2.0.3 which is incompatible.
# Successfully installed pandas-2.0.3

# %%
import sys
import subprocess
if 'google.colab' in sys.modules:
    #!{sys.executable} -m pip install -q git+https://github.com/mobigroup/gmtsar.git@pygmtsar2#subdirectory=pygmtsar
    # !{sys.executable} -m pip install -q pygmtsar==2024.4.17
from pygmtsar import __version__
__version__
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# '2024.4.17'

# %% [markdown]
# # **Load and setup Python Module**

# %%
import xarray as xr
import numpy as np
import pandas as pd
import geopandas as gpd
import json
from dask.distributed import Client
import dask

# %%
# plotting modules
import pyvista as pv
# magic trick for white background
pv.set_plot_theme("document")
import panel
panel.extension('vtk')
from contextlib import contextmanager
import matplotlib.pyplot as plt
@contextmanager
def mpl_settings(settings):
    original_settings = {k: plt.rcParams[k] for k in settings}
    plt.rcParams.update(settings)
    yield
    plt.rcParams.update(original_settings)
plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100
plt.rcParams['figure.titlesize'] = 24
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
# %matplotlib inline
# Out:
# <ipython-input-9-ef9149b47a14>:6: UserWarning: Using Panel interactively in Colab notebooks requires the jupyter_bokeh package to be installed. Install it with:
#
#     !pip install jupyter_bokeh
#
# and try again.
#   panel.extension('vtk')
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1cbd73ac-f035-41eb-a90d-abcb468c0f42'>
#   <div id="b021e22f-8a67-43ff-ad74-7ff718a4e141" data-root-id="1cbd73ac-f035-41eb-a90d-abcb468c0f42" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"360575d4-e881-4e70-9b54-85dc442c67cd":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1cbd73ac-f035-41eb-a90d-abcb468c0f42"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c0045250-f65f-452d-a812-57824c8a2317","attributes":{"plot_id":"1cbd73ac-f035-41eb-a90d-abcb468c0f42","comm_id":"6969a1d1989a469f889ce776e9721738","client_comm_id":"96e2263e6d8e429e96373a99868186cd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"360575d4-e881-4e70-9b54-85dc442c67cd","roots":{"1cbd73ac-f035-41eb-a90d-abcb468c0f42":"b021e22f-8a67-43ff-ad74-7ff718a4e141"},"root_ids":["1cbd73ac-f035-41eb-a90d-abcb468c0f42"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.vtk !== undefined) && ( root.vtk !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# define Pandas display settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# # Descending Orbit **Configuration**
# https://search.asf.alaska.edu/#/?start=2019-01-01T00:00:00Z&resultsLoaded=true&zoom=8.072&center=77.532,22.305&end=2019-02-28T23:59:59Z&productTypes=SLC&path=63-&frame=514-&granule=S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE-SLC

# %%
#Path 63 frame 514
SCENES =  ['S1A_IW_GRDH_1SDV_20190129T004517_20190129T004542_025685_02DA81_7C70'
           'S1A_IW_GRDH_1SDV_20190117T004518_20190117T004543_025510_02D41D_1CAD'
           'S1A_IW_GRDH_1SDV_20190105T004518_20190105T004543_025335_02CDCB_D0A5']
POLARIZATION = 'VV+VH'
ORBIT        = 'D'
SUBSWATH     = 123

# %%
WORKDIR      = '/content'
DATADIR      = '/content/extracted'
# output resolution defined as float value, meter
RESOLUTION   = 200.

# %%
# define DEM and landmask filenames inside data directory
DEM = f'{DATADIR}/dem.nc'
LANDMASK = f'{DATADIR}/landmask.nc'

# %%
import geopandas as gpd
import shapely.geometry

# Define the coordinates for measuring subsidence
coordinates = [
    [78.579643, 22.482553],
    [78.900314, 23.992012],
    [76.449226, 24.409269],
    [76.156799, 22.902924],
    [78.579643, 22.482553]
]

# Create Shapely polygon from the coordinates
polygon = shapely.geometry.Polygon(coordinates)

# Create a GeoDataFrame with the polygon
subsidence_area = gpd.GeoDataFrame(geometry=[polygon])

# Display the GeoDataFrame
print(subsidence_area)
# Out:
#                                                                                               geometry
# 0  POLYGON ((78.57964 22.48255, 78.90031 23.99201, 76.44923 24.40927, 76.15680 22.90292, 78.57964 2...

# %% [markdown]
# # Download and Unpack Datasets (Optional)**bold text**

# %%
# Set these variables to None and you will be prompted to enter your username and password below.
asf_username = 'eu3b2km6k'
asf_password = 'Sunny@90909090/'

# %%
pip show asf_search
# Out:
# Name: asf_search
# Version: 7.1.1
# Summary: Python wrapper for ASF's SearchAPI
# Home-page: https://github.com/asfadmin/Discovery-asf_search.git
# Author: Alaska Satellite Facility Discovery Team
# Author-email: uaf-asf-discovery@alaska.edu
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: ciso8601, dateparser, importlib-metadata, numpy, pytz, requests, shapely, tenacity
# Required-by: pygmtsar

# %%
import asf_search as asf

granules = [
        'S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE',
    'S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831',
    'S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC'
]

results = asf.granule_search(granules)
print(results)
# Out:
# {
#   "features": [
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.579094,
#               22.47662
#             ],
#             [
#               78.92688,
#               24.111303
#             ],
#             [
#               76.453438,
#               24.531622
#             ],
#             [
#               76.137581,
#               22.900173
#             ],
#             [
#               78.579094,
#               22.47662
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 4535233770,
#         "centerLat": 23.5098,
#         "centerLon": 77.5263,
#         "fileID": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE-SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0514_0519_025685_063",
#         "md5sum": "a48c3907b5f30ba023839a0f34c2b806",
#         "orbit": 25685,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-29T00:45:16Z",
#         "processingLevel": "SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-slc-7b420b89/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.zip"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-29T00:45:16Z",
#         "stopTime": "2019-01-29T00:45:43Z",
#         "url": "https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.579094,
#               22.47662
#             ],
#             [
#               78.92688,
#               24.111303
#             ],
#             [
#               76.453438,
#               24.531622
#             ],
#             [
#               76.137581,
#               22.900173
#             ],
#             [
#               78.579094,
#               22.47662
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 68099,
#         "centerLat": 23.5098,
#         "centerLon": 77.5263,
#         "fileID": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE-METADATA_SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.iso.xml",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0514_0519_025685_063",
#         "md5sum": "0182ebaafa8784e6a6a8fc3fb0f220e2",
#         "orbit": 25685,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-29T00:45:16Z",
#         "processingLevel": "METADATA_SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.iso.xml"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-29T00:45:16Z",
#         "stopTime": "2019-01-29T00:45:43Z",
#         "url": "https://datapool.asf.alaska.edu/METADATA_SLC/SA/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.iso.xml"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.569099,
#               22.426361
#             ],
#             [
#               78.915123,
#               24.053244
#             ],
#             [
#               76.468513,
#               24.469538
#             ],
#             [
#               76.153839,
#               22.845829
#             ],
#             [
#               78.569099,
#               22.426361
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 4538558791,
#         "centerLat": 23.4535,
#         "centerLon": 77.5286,
#         "fileID": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831-SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0514_0519_025510_063",
#         "md5sum": "187b4fea9656e56d7d89ddb17d98c8e4",
#         "orbit": 25510,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-17T00:45:17Z",
#         "processingLevel": "SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-slc-7b420b89/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.zip"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-17T00:45:17Z",
#         "stopTime": "2019-01-17T00:45:44Z",
#         "url": "https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.569099,
#               22.426361
#             ],
#             [
#               78.915123,
#               24.053244
#             ],
#             [
#               76.468513,
#               24.469538
#             ],
#             [
#               76.153839,
#               22.845829
#             ],
#             [
#               78.569099,
#               22.426361
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 68095,
#         "centerLat": 23.4535,
#         "centerLon": 77.5286,
#         "fileID": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831-METADATA_SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.iso.xml",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0514_0519_025510_063",
#         "md5sum": "4d3a02600827748ddab51f8126cdcc69",
#         "orbit": 25510,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-17T00:45:17Z",
#         "processingLevel": "METADATA_SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.iso.xml"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-17T00:45:17Z",
#         "stopTime": "2019-01-17T00:45:44Z",
#         "url": "https://datapool.asf.alaska.edu/METADATA_SLC/SA/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.iso.xml"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.568016,
#               22.426466
#             ],
#             [
#               78.914047,
#               24.053623
#             ],
#             [
#               76.467766,
#               24.469793
#             ],
#             [
#               76.153091,
#               22.845814
#             ],
#             [
#               78.568016,
#               22.426466
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 4560018033,
#         "centerLat": 23.4537,
#         "centerLon": 77.5277,
#         "fileID": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC-SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.zip",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0513_0520_025335_063",
#         "md5sum": "521428e98271c40ff2f9544462b59387",
#         "orbit": 25335,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-05T00:45:17Z",
#         "processingLevel": "SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-slc-7b420b89/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.zip"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-05T00:45:17Z",
#         "stopTime": "2019-01-05T00:45:44Z",
#         "url": "https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               78.568016,
#               22.426466
#             ],
#             [
#               78.914047,
#               24.053623
#             ],
#             [
#               76.467766,
#               24.469793
#             ],
#             [
#               76.153091,
#               22.845814
#             ],
#             [
#               78.568016,
#               22.426466
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "IW",
#         "browse": null,
#         "bytes": 68098,
#         "centerLat": 23.4537,
#         "centerLon": 77.5277,
#         "fileID": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC-METADATA_SLC",
#         "fileName": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.iso.xml",
#         "flightDirection": "DESCENDING",
#         "frameNumber": 514,
#         "granuleType": "SENTINEL_1A_FRAME",
#         "groupID": "S1A_IWDV_0513_0520_025335_063",
#         "md5sum": "3b6b705c4ed8fab0db25b4e88bb74557",
#         "orbit": 25335,
#         "pathNumber": 63,
#         "pgeVersion": "002.91",
#         "platform": "Sentinel-1A",
#         "polarization": "VV+VH",
#         "processingDate": "2019-01-05T00:45:17Z",
#         "processingLevel": "METADATA_SLC",
#         "s3Urls": [
#           "s3://asf-ngap2w-p-s1-xml-8cf7476b/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.iso.xml"
#         ],
#         "sceneName": "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC",
#         "sensor": "C-SAR",
#         "startTime": "2019-01-05T00:45:17Z",
#         "stopTime": "2019-01-05T00:45:44Z",
#         "url": "https://datapool.asf.alaska.edu/METADATA_SLC/SA/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.iso.xml"
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config',
#  'landmask.tif',
#  'copernicus_dem.tif',
#  'S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.zip',
#  'Downloads',
#  'S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.zip',
#  'extracted',
#  'S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.zip',
#  'output_directory',
#  'sbas_results',
#  'sample_data']

# %%
import os
import zipfile

# Define the directory containing the ZIP files
zip_dir = '/content/'

# Create a new directory for extracted files if it doesn't exist
extracted_dir = os.path.join(zip_dir, 'extracted')
os.makedirs(extracted_dir, exist_ok=True)

# Get the list of ZIP files in the directory
zip_files = [f for f in os.listdir(zip_dir) if f.endswith('.zip')]

# Extract each ZIP file into the extracted directory
for zip_file in zip_files:
    with zipfile.ZipFile(os.path.join(zip_dir, zip_file), 'r') as zip_ref:
        zip_ref.extractall(extracted_dir)

print("Extraction complete.")
# Out:
# Extraction complete.

# %%
pip install git+https://github.com/asfadmin/asf_search.git
# Out:
# Collecting git+https://github.com/asfadmin/asf_search.git
#   Cloning https://github.com/asfadmin/asf_search.git to /tmp/pip-req-build-a355lno5
#   Running command git clone --filter=blob:none --quiet https://github.com/asfadmin/asf_search.git /tmp/pip-req-build-a355lno5
#   Resolved https://github.com/asfadmin/asf_search.git to commit 1bf62d1f26530151a83e3202dd70d90581840ee2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (2.31.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (2.0.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (2024.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (7.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (1.25.2)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (1.2.0)
# Requirement already satisfied: tenacity==8.2.2 in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (8.2.2)
# Requirement already satisfied: ciso8601 in /usr/local/lib/python3.10/dist-packages (from asf_search==7.1.1) (2.3.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser->asf_search==7.1.1) (2.9.0.post0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->asf_search==7.1.1) (2024.4.16)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->asf_search==7.1.1) (5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->asf_search==7.1.1) (3.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->asf_search==7.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->asf_search==7.1.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->asf_search==7.1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->asf_search==7.1.1) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser->asf_search==7.1.1) (1.16.0)

# %%
import os

# Define the path for the new directory
output_directory = '/content/output_directory'

# Create the directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)
    print(f"Directory '{output_directory}' created successfully!")
else:
    print(f"Directory '{output_directory}' already exists!")

# Now you can use output_directory for further operations
# Out:
# Directory '/content/output_directory' already exists!

# %%
# !pip install sentinelhub
# Out:
# Requirement already satisfied: sentinelhub in /usr/local/lib/python3.10/dist-packages (3.10.2)
# Requirement already satisfied: aenum>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (3.1.15)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (8.1.7)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (0.6.5)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (1.25.2)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (3.2.2)
# Requirement already satisfied: pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (10.3.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (3.6.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.0.0)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.31.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.0.4)
# Requirement already satisfied: tifffile>=2020.9.30 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2024.4.24)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.0.1)
# Requirement already satisfied: tomli-w in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (4.11.0)
# Requirement already satisfied: utm in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (0.7.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=2.2.0->sentinelhub) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (2.0.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->sentinelhub) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->sentinelhub) (0.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->sentinelhub) (1.16.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->sentinelhub) (24.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->sentinelhub) (1.0.0)

# %%
# !python -m pip install asf_tools
# Out:
# Requirement already satisfied: asf_tools in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from asf_tools) (6.0.1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from asf_tools) (1.9.6)
# Requirement already satisfied: gdal>=3.3 in /usr/local/lib/python3.10/dist-packages (from asf_tools) (3.6.4)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from asf_tools) (0.14.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from asf_tools) (1.25.2)
# Requirement already satisfied: pyogrio in /usr/local/lib/python3.10/dist-packages (from asf_tools) (0.7.2)
# Requirement already satisfied: pysheds>=0.3 in /usr/local/lib/python3.10/dist-packages (from asf_tools) (0.3.5)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from asf_tools) (1.3.10)
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.10/dist-packages (from asf_tools) (0.4.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from asf_tools) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from asf_tools) (1.11.4)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from asf_tools) (2.0.4)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from pysheds>=0.3->asf_tools) (2.4.0)
# Requirement already satisfied: geojson in /usr/local/lib/python3.10/dist-packages (from pysheds>=0.3->asf_tools) (3.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from pysheds>=0.3->asf_tools) (0.59.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pysheds>=0.3->asf_tools) (2.2.2)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from pysheds>=0.3->asf_tools) (3.6.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->asf_tools) (67.7.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy->asf_tools) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /usr/local/lib/python3.10/dist-packages (from astropy->asf_tools) (0.2024.4.29.0.28.48)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->asf_tools) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy->asf_tools) (24.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona->asf_tools) (1.16.0)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy->asf_tools) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->asf_tools) (10.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->asf_tools) (2.34.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->asf_tools) (2024.4.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->asf_tools) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pysheds>=0.3->asf_tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pysheds>=0.3->asf_tools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->pysheds>=0.3->asf_tools) (2024.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio->asf_tools) (3.1.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->pysheds>=0.3->asf_tools) (0.42.0)

# %%
import os

# Set the PYTHONPATH to the directory containing the asf_search package
asf_search_path = "/usr/local/lib/python3.10/dist-packages/asf_search"
os.environ["PYTHONPATH"] = asf_search_path

# Check if the PYTHONPATH is set correctly
print("PYTHONPATH set to:", os.environ.get("PYTHONPATH"))
# Out:
# PYTHONPATH set to: /usr/local/lib/python3.10/dist-packages/asf_search

# %%
from pygmtsar import ASF

# %%
from pygmtsar import ASF
import geopandas as gpd
import json

# Define your ASF username and password
asf_username = "eu3b2km6k"
asf_password = "Sunny@90909090/"

# Create an instance of the ASF class
asf = ASF(asf_username, asf_password)

# Define the area of interest (AOI) as a GeoDataFrame
geojson = '''
{
  "type": "Feature",
  "geometry": {
    "type": "Polygon",
    "coordinates": [
      [
        [78.569031, 22.426884],
        [78.915009, 24.053654],
        [76.473228, 24.469149],
        [76.158539, 22.845547],
        [78.569031, 22.426884]
      ]
    ]
  },
  "properties": {}
}
'''

AOI = gpd.GeoDataFrame.from_features([json.loads(geojson)])

# Download scenes from ASF
DATADIR = "/content/Downloads"
SCENES = [
    "S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE",
    "S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831",
    "S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC"
]  # Replace with the list of scenes you want to download
SUBSWATH = "IW"  # Specify the subswath you want to download

# Set these variables to None and you will be prompted to enter your username and password below.
print(asf.download_scenes(DATADIR, SCENES, SUBSWATH))
# Out:
# ASF Downloading Sentinel-1 SLC::   0%|          | 0/3 [00:00<?, ?it/s]
#                                                                  scene
# 0  S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC
# 1  S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831
# 2  S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE

# %%
from pygmtsar import S1

# Scan the data directory for SLC scenes
scanned_scenes = S1.scan_slc(DATADIR)

# Download missed orbits
S1.download_orbits(DATADIR, scanned_scenes)
# Out:
# NOTE: Found multiple scenes for a single day, use function Stack.reframe() to stitch the scenes
# Downloading Sentinel-1 Orbits Index::   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading Sentinel-1 Orbits::   0%|          | 0/3 [00:00<?, ?it/s]
# 0    S1A_OPER_AUX_POEORB_OPOD_20210310T165613_V20190104T225942_20190106T005942.EOF.zip
# 1    S1A_OPER_AUX_POEORB_OPOD_20210310T204435_V20190116T225942_20190118T005942.EOF.zip
# 2    S1A_OPER_AUX_POEORB_OPOD_20210311T003555_V20190128T225942_20190130T005942.EOF.zip
# Name: orbit, dtype: object

# %%
# download Copernicus Global DEM 1 arc-second
Tiles().download_dem(AOI, filename=DEM)
# Out:
# NOTE: Target file exists, return it. Use "skip_exist=False" or omit the filename to allow new downloading.
# <xarray.DataArray 'z' (lat: 7352, lon: 9924)> Size: 292MB
# dask.array<open_dataset-z, shape=(7352, 9924), dtype=float32, chunksize=(2048, 2048), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 79kB 76.16 76.16 76.16 76.16 ... 78.91 78.91 78.92
#   * lat      (lat) float64 59kB 22.43 22.43 22.43 22.43 ... 24.47 24.47 24.47
# Attributes:
#     AREA_OR_POINT:  Point

# %%
# download land mask 1 arc-second
Tiles().download_landmask(AOI, filename=LANDMASK)
# Out:
# NOTE: Target file exists, return it. Use "skip_exist=False" or omit the filename to allow new downloading.
# <xarray.DataArray 'z' (lat: 7352, lon: 9923)> Size: 292MB
# dask.array<open_dataset-z, shape=(7352, 9923), dtype=float32, chunksize=(2048, 2048), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 79kB 76.16 76.16 76.16 76.16 ... 78.91 78.91 78.91
#   * lat      (lat) float64 59kB 22.43 22.43 22.43 22.43 ... 24.47 24.47 24.47

# %%
import os

# Define the directory containing the extracted data
extracted_dir = 'extracted'

# List all files and directories in the extracted directory
extracted_contents = os.listdir(extracted_dir)

# Print the list of extracted contents
print("Extracted contents:")
for item in extracted_contents:
    print(item)
# Out:
# Extracted contents:
# S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE
# S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE
# S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE

# %%
import os

# Get the current working directory
current_dir = os.getcwd()

# Assuming the extracted directory is in the current working directory
extracted_dir = os.path.join(current_dir, 'extracted')

print("Path to extracted directory:", extracted_dir)
# Out:
# Path to extracted directory: /content/extracted

# %%
DATADIR = "/content/extracted"

# %%
import os

# List files in the directory
files = os.listdir('/content/extracted')

# Print the list of files
print("Files in the /content directory:")
print(files)
# Out:
# Files in the /content directory:
# ['S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE', 'S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE', 'S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE']

# %%
from shapely.geometry import Polygon

# %% [markdown]
# # Run Local Dask **Cluster**

# %%
# simple Dask initialization
if 'client' in globals():
    client.close()
client = Client()
client
# Out:
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:43499
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:42615'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:34879'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:45103'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:35941'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:32931'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40089'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:44367'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:44611'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:43285'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:32795'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:39953'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40187'
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:33521', name: 0, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:33521
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60188
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:43017', name: 3, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:43017
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60204
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:44057', name: 4, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:44057
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60214
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:39693', name: 5, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:39693
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60222
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:42939', name: 6, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:42939
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60236
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:42029', name: 2, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:42029
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60242
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:38917', name: 7, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38917
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60256
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:40923', name: 9, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:40923
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60268
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:44033', name: 1, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:44033
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60284
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:39917', name: 10, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:39917
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60308
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:42031', name: 8, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:42031
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60332
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:45367', name: 11, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:45367
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:60342
# INFO:distributed.scheduler:Receive client connection: Client-8cf855c1-0861-11ef-b7aa-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:52276
# <Client: 'tcp://127.0.0.1:43499' processes=12 threads=96, memory=334.56 GiB>

# %% [markdown]
# # Select Original Secenes and **Orbits**
# Use filters to find required subswath, polarization and orbit in original scenes .SAFE directories in the data directory.

# %%
scenes = S1.scan_slc(DATADIR, subswath=SUBSWATH)
# Out:
# NOTE: Found multiple scenes for a single day, use function Stack.reframe() to stitch the scenes

# %%
sbas = Stack(WORKDIR, drop_if_exists=True).set_scenes(scenes)
sbas.to_dataframe()
# Out:
# NOTE: auto set reference scene 2019-01-05. You can change it like Stack.set_reference("2022-01-20")
#                       datetime orbit mission polarization  subswath  \
# date
# 2019-01-05 2019-01-05 00:45:19     D     S1A           VH         1
# 2019-01-05 2019-01-05 00:45:19     D     S1A           VV         1
# 2019-01-17 2019-01-17 00:45:19     D     S1A           VH         1
# 2019-01-17 2019-01-17 00:45:19     D     S1A           VV         1
# 2019-01-29 2019-01-29 00:45:16     D     S1A           VH         1
# 2019-01-29 2019-01-29 00:45:16     D     S1A           VV         1
#
#                                                                                                        datapath  \
# date
# 2019-01-05  /content/extracted/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE/meas...
# 2019-01-05  /content/extracted/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE/meas...
# 2019-01-17  /content/extracted/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE/meas...
# 2019-01-17  /content/extracted/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE/meas...
# 2019-01-29  /content/extracted/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE/meas...
# 2019-01-29  /content/extracted/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE/meas...
#
#                                                                                                        metapath  \
# date
# 2019-01-05  /content/extracted/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE/anno...
# 2019-01-05  /content/extracted/S1A_IW_SLC__1SDV_20190105T004517_20190105T004544_025335_02CDCB_10CC.SAFE/anno...
# 2019-01-17  /content/extracted/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE/anno...
# 2019-01-17  /content/extracted/S1A_IW_SLC__1SDV_20190117T004517_20190117T004544_025510_02D41D_5831.SAFE/anno...
# 2019-01-29  /content/extracted/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE/anno...
# 2019-01-29  /content/extracted/S1A_IW_SLC__1SDV_20190129T004516_20190129T004543_025685_02DA81_B8DE.SAFE/anno...
#
#                                                                                                    orbitpath  \
# date
# 2019-01-05  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210310T165613_V20190104T225942_20190106T005942.EOF
# 2019-01-05  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210310T165613_V20190104T225942_20190106T005942.EOF
# 2019-01-17  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210310T204435_V20190116T225942_20190118T005942.EOF
# 2019-01-17  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210310T204435_V20190116T225942_20190118T005942.EOF
# 2019-01-29  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210311T003555_V20190128T225942_20190130T005942.EOF
# 2019-01-29  /content/extracted/S1A_OPER_AUX_POEORB_OPOD_20210311T003555_V20190128T225942_20190130T005942.EOF
#
#                                                                                                        geometry
# date
# 2019-01-05  MULTIPOLYGON (((78.89142 23.94398, 78.84590 23.95212, 78.80081 23.96016, 78.75613 23.96812, 78.7...
# 2019-01-05  MULTIPOLYGON (((78.89142 23.94398, 78.84590 23.95212, 78.80081 23.96016, 78.75613 23.96812, 78.7...
# 2019-01-17  MULTIPOLYGON (((78.89248 23.94358, 78.84696 23.95172, 78.80186 23.95976, 78.75717 23.96773, 78.7...
# 2019-01-17  MULTIPOLYGON (((78.89248 23.94358, 78.84696 23.95172, 78.80186 23.95976, 78.75717 23.96773, 78.7...
# 2019-01-29  MULTIPOLYGON (((78.92786 24.11133, 78.88010 24.11985, 78.83281 24.12827, 78.78596 24.13660, 78.7...
# 2019-01-29  MULTIPOLYGON (((78.92786 24.11133, 78.88010 24.11985, 78.83281 24.12827, 78.78596 24.13660, 78.7...

# %%
sbas.plot_scenes(AOI=AOI, aspect='equal')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-e1b59879ade7> in <cell line: 1>()
# ----> 1 sbas.plot_scenes(AOI=AOI, aspect='equal')
#
# /usr/local/lib/python3.10/dist-packages/pygmtsar/Stack.py in plot_scenes(self, dem, caption, cmap, aspect, **kwargs)
#     135         alpha = alpha if alpha>=0.002 else 0.002
#     136         gdf.reset_index().plot(color=[colors[k] for k in gdf.index], alpha=alpha, edgecolor='black', ax=plt.gca())
# --> 137         self.plot_AOI(**kwargs)
#     138         self.plot_POI(**kwargs)
#     139         if aspect is not None:
#
# /usr/local/lib/python3.10/dist-packages/pygmtsar/Stack.py in plot_AOI(geometry, **kwargs)
#      90         else:
#      91             boundary_color = kwargs['boundary_color']
# ---> 92         boundaries = geometry.boundary
#      93         geometry[~boundaries.is_empty].boundary.plot(ax=plt.gca(), color=boundary_color)
#      94         geometry[boundaries.is_empty].plot(ax=plt.gca(), color=boundary_color)
#
# AttributeError: 'dict' object has no attribute 'boundary'

# %%
sbas.compute_reframe(AOI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a3c753b07ef9> in <cell line: 1>()
# ----> 1 sbas.compute_reframe(AOI)
#
# NameError: name 'sbas' is not defined
